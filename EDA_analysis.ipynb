# %% [markdown]
# Notebook 5: EDA - Technology & Pipeline Analysis
# * Goal: Visualize the "how" (technology) and "when" (pipeline) of demand.

# %% [markdown]
# Block 1: Load Data for Notebook 5
#
# This block loads the new aggregated files we need for this notebook's specific visualizations.

# %%
# Load the new datasets required for this notebook
df_tech = pd.read_csv('tech_demand_ts.csv')
df_pipeline = pd.read_csv('pipeline_status_ts.csv')

print("Loaded 'tech_demand_ts.csv' and 'pipeline_status_ts.csv'.")
# Out:
# Loaded 'tech_demand_ts.csv' and 'pipeline_status_ts.csv'.

# %% [markdown]
# Block 2: Visualization 1 - Technology Share Over Time
#
# This plot shows how the mix of reactor types (PWR, BWR, etc.) has evolved.

# %%
print("\nGenerating Viz 1: Technology Share (1950-Present)...")

# Filter out year 0
df_tech_filtered = df_tech[df_tech['Year'] > 1950]

fig_tech_share = px.area(
    df_tech_filtered,
    x='Year',
    y='Total Thermal Capacity, MWt',
    color='Type',
    title='Global Thermal Capacity by Reactor Type (1950-Present)'
)
fig_tech_share.update_layout(xaxis_title='Year', yaxis_title='Total Thermal Capacity (MWt)', legend_title='Reactor Type')
fig_tech_share.show()
# Out:
# Generating Viz 1: Technology Share (1950-Present)...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f3ecafe6-09cf-45c2-ab6e-6b8dbe594219" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3ecafe6-09cf-45c2-ab6e-6b8dbe594219")) {                    Plotly.newPlot(                        "f3ecafe6-09cf-45c2-ab6e-6b8dbe594219",                        [{"fillpattern":{"shape":""},"hovertemplate":"Type=BWR\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Thermal Capacity, MWt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BWR","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"BWR","orientation":"v","showlegend":true,"stackgroup":"1","x":[1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[1850,4807,9768,15682,19140,35723,41182,47563,47563,52867,52867,58601,61854,69352,69352,91581,105387,116471,123932,126368,132200,132200,132200,132200,132200,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953,136953],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Type=FBR\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Thermal Capacity, MWt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"FBR","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"FBR","orientation":"v","showlegend":true,"stackgroup":"1","x":[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,1470,3570,3570,3570,3570,3570,3570,3570,3570,3570,3570],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Type=GCR\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Thermal Capacity, MWt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GCR","line":{"color":"#00cc96"},"marker":{"symbol":"circle"},"mode":"lines","name":"GCR","orientation":"v","showlegend":true,"stackgroup":"1","x":[1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[3000,6000,6000,6000,6000,10723,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346,12346],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Type=HTGR\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Thermal Capacity, MWt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"HTGR","line":{"color":"#ab63fa"},"marker":{"symbol":"circle"},"mode":"lines","name":"HTGR","orientation":"v","showlegend":true,"stackgroup":"1","x":[2021,2022,2023,2024],"xaxis":"x","y":[500,500,500,500],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Type=LWGR\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Thermal Capacity, MWt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LWGR","line":{"color":"#FFA15A"},"marker":{"symbol":"circle"},"mode":"lines","name":"LWGR","orientation":"v","showlegend":true,"stackgroup":"1","x":[1974,197 ...

# %% [markdown]
# Block 3: Visualization 2 - Demand Pipeline (Operational vs. Construction)
#
# This is a key leading indicator, comparing the active fleet to the future fleet.

# %%
print("\nGenerating Viz 2: Demand Pipeline (Operational vs. Under Construction)...")

# Filter the pipeline data for the two statuses we care about
statuses_to_plot = ['Operational', 'Under Construction']

# **THE FIX IS HERE**: Filter out Year 0 by selecting Years > 1950
df_pipeline_viz_filtered = df_pipeline[
    (df_pipeline['Status'].isin(statuses_to_plot)) &
    (df_pipeline['Year'] > 1950)
]

# Create the line chart
fig_pipeline = px.line(
    df_pipeline_viz_filtered, # Use the new filtered DataFrame
    x='Year',
    y='Reactor Count',
    color='Status',  # Creates a separate line for each status
    title='Reactor Pipeline: Operational vs. Under Construction (1950-Present)'
)

fig_pipeline.update_layout(
    xaxis_title='Year',
    yaxis_title='Number of Reactors',
    legend_title='Status'
)

fig_pipeline.show()
# Out:
# Generating Viz 2: Demand Pipeline (Operational vs. Under Construction)...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1662c939-ec13-4fa0-b0c6-791d0c3f2bcc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1662c939-ec13-4fa0-b0c6-791d0c3f2bcc")) {                    Plotly.newPlot(                        "1662c939-ec13-4fa0-b0c6-791d0c3f2bcc",                        [{"hovertemplate":"Status=Operational\u003cbr\u003eYear=%{x}\u003cbr\u003eReactor Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Operational","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Operational","orientation":"v","showlegend":true,"x":[1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[3,6,9,15,23,35,44,53,58,66,70,88,106,118,133,160,189,210,230,241,250,258,262,267,273,278,282,286,289,293,297,303,305,311,313,317,319,321,324,324,325,330,334,339,343,348,358,368,372,381,387,392,398,404,409,415],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"marker":{"line":{"color":"#283442"}},"type":"scatter"}],"parco ...

# %% [markdown]
# Block 4: Visualization 3 - Attrition (Permanent Shutdowns)
#
# This chart visualizes "demand destruction"—the rate at which reactors are being retired.

# %%
print("\nGenerating Viz 3: Attrition (1950-Present)...")

# Filter for 'Permanent Shutdown' and years > 1950
df_shutdown_filtered = df_pipeline[
    (df_pipeline['Status'] == 'Permanent Shutdown') &
    (df_pipeline['Year'] > 1950)
]

fig_shutdown = px.area(
    df_shutdown_filtered,
    x='Year',
    y='Reactor Count',
    title='Reactors in "Permanent Shutdown" Status Over Time (1950-Present)'
)
fig_shutdown.update_layout(xaxis_title='Year', yaxis_title='Number of Shutdown Reactors')
fig_shutdown.show()
# Out:
# Generating Viz 3: Attrition (1950-Present)...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f8a4881b-490f-4d4d-a34d-664d2313a586" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8a4881b-490f-4d4d-a34d-664d2313a586")) {                    Plotly.newPlot(                        "f8a4881b-490f-4d4d-a34d-664d2313a586",                        [{"fillpattern":{"shape":""},"hovertemplate":"Year=%{x}\u003cbr\u003eReactor Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"stackgroup":"1","x":[1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[1,1,2,5,6,11,15,15,24,33,40,47,55,65,70,72,74,87,96,105,118,121,131,141,147,150,151,154,159,164,168,167,170,170,168,165,158,144,138,135,135,133,133,131,128,123,121,118,118,113,107,102,100,92,91,89,86,84,71,68,62,60,53,50,46,39,28,22,12,8,4],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks" ...
